# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('Google-Playstore-Full.csv', encoding='latin-1',low_memory=False)

# %%
data.columns
# Out:
# Index(['App Name', 'Category', 'Rating', 'Reviews', 'Installs', 'Size',
#        'Price', 'Content Rating', 'Last Updated', 'Minimum Version',
#        'Latest Version', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
data['Unnamed: 14'].value_counts()
# Out:
# 9.1    1
# Name: Unnamed: 14, dtype: int64

# %%
data.drop(columns=['Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14'],inplace=True)

# %%
data.head(10)
# Out:
#                                             App Name          Category  \
# 0                           DoorDash - Food Delivery    FOOD_AND_DRINK
# 1  TripAdvisor Hotels Flights Restaurants Attract...  TRAVEL_AND_LOCAL
# 2                                             Peapod          SHOPPING
# 3                    foodpanda - Local Food Delivery    FOOD_AND_DRINK
# 4                          My CookBook Pro (Ad Free)    FOOD_AND_DRINK
# 5                            Safeway Online Shopping    FOOD_AND_DRINK
# 6              Yelp: Food, Shopping, Services Nearby  TRAVEL_AND_LOCAL
# 7                             Talabat: Food Delivery    FOOD_AND_DRINK
# 8     Fast Food Locator | Worldwide Fast Food Finder  TRAVEL_AND_LOCAL
# 9                          Allrecipes Dinner Spinner    FOOD_AND_DRINK
#
#         Rating  Reviews      Installs                Size  Price  \
# 0  4.548561573   305034    5,000,000+  Varies with device      0
# ...

# %%
len(data['Reviews'])
# Out:
# 267052

# %%
data.shape
# Out:
# (267052, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267052 entries, 0 to 267051
# Data columns (total 11 columns):
# App Name           267051 non-null object
# Category           267051 non-null object
# Rating             267052 non-null object
# Reviews            267051 non-null object
# Installs           267052 non-null object
# Size               267052 non-null object
# Price              267052 non-null object
# Content Rating     267052 non-null object
# Last Updated       267052 non-null object
# Minimum Version    267051 non-null object
# Latest Version     267049 non-null object
# dtypes: object(11)
# memory usage: 22.4+ MB

# %%
data.drop(columns=['Last Updated','Minimum Version','Latest Version'],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267052 entries, 0 to 267051
# Data columns (total 8 columns):
# App Name          267051 non-null object
# Category          267051 non-null object
# Rating            267052 non-null object
# Reviews           267051 non-null object
# Installs          267052 non-null object
# Size              267052 non-null object
# Price             267052 non-null object
# Content Rating    267052 non-null object
# dtypes: object(8)
# memory usage: 16.3+ MB

# %%
data.shape
# Out:
# (267052, 8)

# %%
data.fillna({'Reviews':'0'},inplace=True)

# %%
data
# Out:
#                                                  App Name  \
# 0                                DoorDash - Food Delivery
# 1       TripAdvisor Hotels Flights Restaurants Attract...
# 2                                                  Peapod
# 3                         foodpanda - Local Food Delivery
# 4                               My CookBook Pro (Ad Free)
# 5                                 Safeway Online Shopping
# 6                   Yelp: Food, Shopping, Services Nearby
# 7                                  Talabat: Food Delivery
# 8          Fast Food Locator | Worldwide Fast Food Finder
# 9                               Allrecipes Dinner Spinner
# 10                                    ???????????????????
# 11                          Eat24 Food Delivery & Takeout
# 12                                            FreshDirect
# 13                      Easy Healthy Recipes for free app
# 14                                     Domino's Pizza USA
# ...

# %%
data=data[data['Content Rating']=='Everyone']

# %%
data.drop(columns=['Content Rating'],inplace=True)
# Out:
# C:\Users\DIPAM\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data['Reviews']=data['Reviews'].astype(int)
# Out:
# C:\Users\DIPAM\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['Rating']=data['Rating'].astype(float)
# Out:
# C:\Users\DIPAM\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['Price']=data['Price'].str.replace('$','')
# Out:
# C:\Users\DIPAM\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                                                  App Name  \
# 0                                DoorDash - Food Delivery
# 1       TripAdvisor Hotels Flights Restaurants Attract...
# 2                                                  Peapod
# 3                         foodpanda - Local Food Delivery
# 4                               My CookBook Pro (Ad Free)
# 5                                 Safeway Online Shopping
# 7                                  Talabat: Food Delivery
# 8          Fast Food Locator | Worldwide Fast Food Finder
# 9                               Allrecipes Dinner Spinner
# 10                                    ???????????????????
# 11                          Eat24 Food Delivery & Takeout
# 12                                            FreshDirect
# 13                      Easy Healthy Recipes for free app
# 14                                     Domino's Pizza USA
# 15                             iFood - Delivery de Comida
# ...

# %%
data.shape
# Out:
# (241578, 7)

# %%
a=data.groupby('Category')['Rating'].mean().reset_index()

# %%
data=data.merge(a, on="Category")

# %%
data.shape
# Out:
# (241578, 8)

# %%
data['Installs']=data['Installs'].str.replace('+','')

# %%
data['Installs']=data['Installs'].str.replace(',','')

# %%
data=data[data['Size']=='Varies with device']

# %%
data.drop(columns=['Size'],inplace=True)

# %%
data.head()
# Out:
#                     App Name        Category  Rating_x  Reviews Installs  \
# 0   DoorDash - Food Delivery  FOOD_AND_DRINK  4.548562   305034  5000000
# 2  My CookBook Pro (Ad Free)  FOOD_AND_DRINK  4.647752     2291    10000
# 4     Talabat: Food Delivery  FOOD_AND_DRINK  4.495085   142618  5000000
# 5  Allrecipes Dinner Spinner  FOOD_AND_DRINK  4.545353    67514  5000000
# 6        ???????????????????  FOOD_AND_DRINK  4.511622    28996  1000000
#
#   Price  Rating_y
# 0     0   4.31243
# 2  5.99   4.31243
# 4     0   4.31243
# 5     0   4.31243
# 6     0   4.31243

# %%
X=data.drop(columns=['App Name','Category','Rating_x']).iloc[:,3].values

# %%
X.shape
# Out:
# (10351,)

# %%
y=data.iloc[:,2].values

# %%
y.shape
# Out:
# (10351,)

# %%
y
# Out:
# array([4.54856157, 4.64775229, 4.49508476, ..., 4.44736862, 4.00276232,
#        4.7186656 ])

# %%
X.shape
# Out:
# (10351,)

# %%
plt.scatter(X,y)

# %%
plt.plot(X,y)

# %%
X=data.drop(columns=['App Name','Category','Rating_x']).iloc[:,:].values

# %%
X.shape
# Out:
# (10351, 4)

# %%
y.shape
# Out:
# (10351,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=7)

# %%
X_train
# Out:
# array([[554, '1000', '3.99', 4.269349786078708],
#        [68, '1000', '0', 4.479367547198434],
#        [13, '1000', '0', 4.039533500134716],
#        ...,
#        [10947, '500000', '0', 4.231529061873541],
#        [27609, '5000000', '0', 4.203247193672469],
#        [4584, '500000', '0', 4.28140203275657]], dtype=object)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regre=RandomForestRegressor(n_estimators=300)

# %%
regre.fit(X,y)
# Out:
# C:\Users\DIPAM\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_pred=regre.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7235730049002093
